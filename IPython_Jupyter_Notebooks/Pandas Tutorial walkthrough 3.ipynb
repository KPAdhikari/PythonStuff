# %%
# Pandas Tutorial Walkthrough 3
Pandas is an open source library in Python for data analysis, data manipulation and data visualization.

Built on top of NumPy - Numerical Python.


## Referenes:
* https://www.youtube.com/watch?v=5_QXMwezPJE&t=182s
# Out:
#   File "<ipython-input-3-3dc2158b147c>", line 2
#     Pandas is an open source library in Python for data analysis, data manipulation and data visualization.
#                     ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
pd.read_table('data/chipotle.tsv')
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %% [markdown]
# The copy of the same data file chipotle.tsv (which I had downloaded from https://github.com/justmarkham/pandas-videos/tree/master/data) can also be reached directly from the web as follows.

# %%
import pandas as pd

# %%
pd.read_table('http://bit.ly/chiporders')
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
pd.read_table('data/drinks.csv')
# Out:
#     country,beer_servings,spirit_servings,wine_servings,total_litres_of_pure_alcohol,continent
# 0                           Afghanistan,0,0,0,0.0,Asia
# 1                         Albania,89,132,54,4.9,Europe
# 2                           Algeria,25,0,14,0.7,Africa
# 3                      Andorra,245,138,312,12.4,Europe
# 4                          Angola,217,57,45,5.9,Africa
# 5       Antigua & Barbuda,102,128,45,4.9,North America
# 6               Argentina,193,25,221,8.3,South America
# 7                         Armenia,21,179,11,3.8,Europe
# 8                    Australia,261,72,212,10.4,Oceania
# 9                        Austria,279,75,191,9.7,Europe
# 10                       Azerbaijan,21,46,5,1.3,Europe
# 11                Bahamas,122,176,51,6.3,North America
# 12                            Bahrain,42,63,7,2.0,Asia
# 13                           Bangladesh,0,0,0,0.0,Asia
# 14               Barbados,143,173,36,6.3,North America
# ...

# %%
pd.read_table('data/u.user')
# Out:
#           1|24|M|technician|85711
# 0              2|53|F|other|94043
# 1             3|23|M|writer|32067
# 2         4|24|M|technician|43537
# 3              5|33|F|other|15213
# 4          6|42|M|executive|98101
# 5      7|57|M|administrator|91344
# 6      8|36|M|administrator|05201
# 7            9|29|M|student|01002
# 8            10|53|M|lawyer|90703
# 9             11|39|F|other|30329
# 10            12|28|F|other|06405
# 11         13|47|M|educator|29206
# 12        14|45|M|scientist|55106
# 13         15|49|F|educator|97301
# 14    16|21|M|entertainment|10309
# 15       17|30|M|programmer|06355
# 16            18|35|F|other|37212
# 17        19|40|M|librarian|02138
# 18        20|42|F|homemaker|95660
# 19           21|26|M|writer|30068
# 20           22|25|M|writer|40206
# 21           23|30|F|artist|48197
# 22           24|21|F|artist|94533
# 23         25|39|M|engineer|55107
# 24         26|49|M|engineer|21044
# 25        27|40|F|librarian|30030
# ...

# %%
pd.read_table('data/ufo.csv')
# Out:
#        City,Colors Reported,Shape Reported,State,Time
# 0                  Ithaca,,TRIANGLE,NY,6/1/1930 22:00
# 1               Willingboro,,OTHER,NJ,6/30/1930 20:00
# 2                    Holyoke,,OVAL,CO,2/15/1931 14:00
# 3                     Abilene,,DISK,KS,6/1/1931 13:00
# 4      New York Worlds Fair,,LIGHT,NY,4/18/1933 19:00
# 5                Valley City,,DISK,ND,9/15/1934 15:30
# 6               Crater Lake,,CIRCLE,CA,6/15/1935 0:00
# 7                        Alma,,DISK,MI,7/15/1936 0:00
# 8                  Eklutna,,CIGAR,AK,10/15/1936 17:00
# 9                 Hubbard,,CYLINDER,OR,6/15/1937 0:00
# 10                  Fontana,,LIGHT,CA,8/15/1937 21:00
# 11               Waterloo,,FIREBALL,AL,6/1/1939 20:00
# 12               Belton,RED,SPHERE,SC,6/30/1939 20:00
# 13                      Keokuk,,OVAL,IA,7/7/1939 2:00
# 14                  Ludington,,DISK,MI,6/1/1941 13:00
# 15              Forest Home,,CIRCLE,CA,7/2/1941 11:30
# ...

# %%
pd.read_table('data/imdb_1000.csv')
# Out:
#     star_rating,title,content_rating,genre,duration,actors_list
# 0    9.3,The Shawshank Redemption,R,Crime,142,"[u'T...
# 1    9.2,The Godfather,R,Crime,175,"[u'Marlon Brand...
# 2    9.1,The Godfather: Part II,R,Crime,200,"[u'Al ...
# 3    9,The Dark Knight,PG-13,Action,152,"[u'Christi...
# 4    8.9,Pulp Fiction,R,Crime,154,"[u'John Travolta...
# 5    8.9,12 Angry Men,NOT RATED,Drama,96,"[u'Henry ...
# 6    8.9,"The Good, the Bad and the Ugly",NOT RATED...
# 7    8.9,The Lord of the Rings: The Return of the K...
# 8    8.9,Schindler's List,R,Biography,195,"[u'Liam ...
# 9    8.9,Fight Club,R,Drama,139,"[u'Brad Pitt', u'E...
# 10   8.8,The Lord of the Rings: The Fellowship of t...
# 11   8.8,Inception,PG-13,Action,148,"[u'Leonardo Di...
# 12   8.8,Star Wars: Episode V - The Empire Strikes ...
# 13   8.8,Forrest Gump,PG-13,Drama,142,"[u'Tom Hanks...
# 14   8.8,The Lord of the Rings: The Two Towers,PG-1...
# 15   8.7,Interstellar,PG-13,Adventure,169,"[u'Matth...
# ...

# %%
pd.read_table('data/titanic_test.csv')
# Out:
#     PassengerId,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked
# 0    892,3,"Kelly, Mr. James",male,34.5,0,0,330911,...
# 1    893,3,"Wilkes, Mrs. James (Ellen Needs)",femal...
# 2    894,2,"Myles, Mr. Thomas Francis",male,62,0,0,...
# 3    895,3,"Wirz, Mr. Albert",male,27,0,0,315154,8....
# 4    896,3,"Hirvonen, Mrs. Alexander (Helga E Lindq...
# 5    897,3,"Svensson, Mr. Johan Cervin",male,14,0,0...
# 6    898,3,"Connolly, Miss. Kate",female,30,0,0,330...
# 7    899,2,"Caldwell, Mr. Albert Francis",male,26,1...
# 8    900,3,"Abrahim, Mrs. Joseph (Sophie Halaut Eas...
# 9    901,3,"Davies, Mr. John Samuel",male,21,2,0,A/...
# 10   902,3,"Ilieff, Mr. Ylio",male,,0,0,349220,7.89...
# 11   903,1,"Jones, Mr. Charles Cresson",male,46,0,0...
# 12   904,1,"Snyder, Mrs. John Pillsbury (Nelle Stev...
# 13   905,2,"Howard, Mr. Benjamin",male,63,1,0,24065...
# 14   906,1,"Chaffee, Mrs. Herbert Fuller (Carrie Co...
# 15   907,2,"del Carlo, Mrs. Sebastiano (Argenia Gen...
# ...

# %%
pd.read_table('data/titanic_train.csv')
# Out:
#     PassengerId,Survived,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked
# 0    1,0,3,"Braund, Mr. Owen Harris",male,22,1,0,A/...
# 1    2,1,1,"Cumings, Mrs. John Bradley (Florence Br...
# 2    3,1,3,"Heikkinen, Miss. Laina",female,26,0,0,S...
# 3    4,1,1,"Futrelle, Mrs. Jacques Heath (Lily May ...
# 4    5,0,3,"Allen, Mr. William Henry",male,35,0,0,3...
# 5    6,0,3,"Moran, Mr. James",male,,0,0,330877,8.45...
# 6    7,0,1,"McCarthy, Mr. Timothy J",male,54,0,0,17...
# 7    8,0,3,"Palsson, Master. Gosta Leonard",male,2,...
# 8    9,1,3,"Johnson, Mrs. Oscar W (Elisabeth Vilhel...
# 9    10,1,2,"Nasser, Mrs. Nicholas (Adele Achem)",f...
# 10   11,1,3,"Sandstrom, Miss. Marguerite Rut",femal...
# 11   12,1,1,"Bonnell, Miss. Elizabeth",female,58,0,...
# 12   13,0,3,"Saundercock, Mr. William Henry",male,2...
# 13   14,0,3,"Andersson, Mr. Anders Johan",male,39,1...
# 14   15,0,3,"Vestrom, Miss. Hulda Amanda Adolfina",...
# 15   16,1,2,"Hewlett, Mrs. (Mary D Kingcome) ",fema...
# ...
